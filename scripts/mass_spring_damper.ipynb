# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# Variables
curr_dir = Path(".")
build_dir = curr_dir / ".." / "build"

# %%
# Read csv data
df = pd.read_csv(build_dir / "apps" / "mass_spring_damper" / "output.csv")

# %%
# Plot
plt.figure()
plt.plot(df["t"], df["y0"])
plt.grid()
plt.xlabel("Time (s)")
plt.ylabel("Distance (m)")
plt.show()
